# %% [markdown]
# ### Instructor Demo: Simple Moving Averages
#
# This program reads in the CSV datasets of Netflix (NFLX) and plots the 20, 50, and 100 Simple Moving Averages (SMA) using the `rolling` function, `window` parameter, and `mean` function.

# %%
# Import libraries and dependencies
import pandas as pd
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# ### Read CSV in as DataFrame

# %%
# Set file path
nflx_data = Path("../Resources/nflx.csv")

# Read the CSV into a DataFrame and set the 'date' column as a datetime index
nflx_df = pd.read_csv(nflx_data, index_col="date", infer_datetime_format=True, parse_dates=True)
nflx_df.sort_index(inplace=True)
# Display a few records
nflx_df.head()
# Out:
#              close
# date
# 2009-05-18  5.5386
# 2009-05-19  5.6614
# 2009-05-20  5.7500
# 2009-05-21  5.5871
# 2009-05-22  5.5429

# %% [markdown]
# ### Plot Daily Closing Price of NFLX

# %%
# Plot DataFrame
nflx_df.plot()

# %% [markdown]
# ### Calculate 20-Day Simple Moving Average (SMA20)

# %%
# Calculate 20-day Simple Moving Average for NFLX Closing Prices
nflx_sma_20 = nflx_df.rolling(window=20).mean()
nflx_sma_20
# Out:
#                  close
# date
# 2009-05-18         NaN
# 2009-05-19         NaN
# 2009-05-20         NaN
# 2009-05-21         NaN
# 2009-05-22         NaN
# 2009-05-26         NaN
# 2009-05-27         NaN
# 2009-05-28         NaN
# 2009-05-29         NaN
# 2009-06-01         NaN
# 2009-06-02         NaN
# 2009-06-03         NaN
# 2009-06-04         NaN
# 2009-06-05         NaN
# 2009-06-08         NaN
# 2009-06-09         NaN
# 2009-06-10         NaN
# 2009-06-11         NaN
# 2009-06-12         NaN
# 2009-06-15    5.610495
# 2009-06-16    5.603780
# 2009-06-17    5.609280
# 2009-06-18    5.616850
# 2009-06-19    5.634565
# 2009-06-22    5.647065
# 2009-06-23    5.643355
# 2009-06-24    5.648070
# 2009-06-25    5.666430
# 2009-06-26    5.673215
# 2009-06-29    5.675070
# ...                ...
# 2019-04-04  362.279500
# 2019-04-05  363.074000
# 2019-04-08  363.201500
# 2019-04-09  363.623500
# 2019-04-10  363.759000
# 2019-04-11  364.200500
# 2019-04-12  363.684500
# 2019-04-15  362.956000
# 2019-04-16  362.990000
# 2019-04-17  361.966000
# 2019-04-18  361.090000
# 2019-04-22  361.906500
# 2019-04-23  362.689500
# 2019-04-24  363.402500
# 2019-04-25  364.150500
# 2019-04-26  365.162500
# 2019-04-29  365.926000
# 2019-04-30  366.105000
# 2019-05-01  366.659500
# 2019-05-02  367.125000
# 2019-05-03  367.982500
# 2019-05-06  368.641500
# 2019-05-07  369.094000
# 2019-05-08  369.077000
# 2019-05-09  369.018500
# 2019-05-10  368.688000
# 2019-05-13  368.394000
# 2019-05-14  368.231000
# 2019-05-15  368.007500
# 2019-05-16  368.236000
#
# [2517 rows x 1 columns]

# %% [markdown]
# ### Calculate 50-Day Simple Moving Average (SMA50)

# %%
# Calculate 50-day Simple Moving Average for NFLX Closing Prices
nflx_sma_50 = nflx_df.rolling(window=50).mean()
nflx_sma_50
# Out:
#                close
# date
# 2009-05-18       NaN
# 2009-05-19       NaN
# 2009-05-20       NaN
# 2009-05-21       NaN
# 2009-05-22       NaN
# 2009-05-26       NaN
# 2009-05-27       NaN
# 2009-05-28       NaN
# 2009-05-29       NaN
# 2009-06-01       NaN
# 2009-06-02       NaN
# 2009-06-03       NaN
# 2009-06-04       NaN
# 2009-06-05       NaN
# 2009-06-08       NaN
# 2009-06-09       NaN
# 2009-06-10       NaN
# 2009-06-11       NaN
# 2009-06-12       NaN
# 2009-06-15       NaN
# 2009-06-16       NaN
# 2009-06-17       NaN
# 2009-06-18       NaN
# 2009-06-19       NaN
# 2009-06-22       NaN
# 2009-06-23       NaN
# 2009-06-24       NaN
# 2009-06-25       NaN
# 2009-06-26       NaN
# 2009-06-29       NaN
# ...              ...
# 2019-04-04  355.7290
# 2019-04-05  356.5054
# 2019-04-08  356.9726
# 2019-04-09  357.5536
# 2019-04-10  358.2540
# 2019-04-11  358.7938
# 2019-04-12  359.0266
# 2019-04-15  359.2070
# 2019-04-16  359.3694
# 2019-04-17  359.3480
# 2019-04-18  359.5112
# 2019-04-22  360.1638
# 2019-04-23  360.8502
# 2019-04-24  361.4202
# 2019-04-25  361.5874
# 2019-04-26  362.0490
# 2019-04-29  362.3042
# 2019-04-30  362.5776
# 2019-05-01  362.9154
# 2019-05-02  363.2984
# 2019-05-03  363.8596
# 2019-05-06  364.1726
# 2019-05-07  364.3036
# 2019-05-08  364.2916
# 2019-05-09  364.2892
# 2019-05-10  364.3480
# 2019-05-13  364.1068
# 2019-05-14  363.9982
# 2019-05-15  364.0120
# 2019-05-16  364.0060
#
# [2517 rows x 1 columns]

# %% [markdown]
# ### Calculate 100-Day Simple Moving Average (SMA100)

# %%
# Calculate 100-day Simple Moving Average for NFLX Closing Prices
nflx_sma_100 = nflx_df.rolling(window=100).mean()
nflx_sma_100
# Out:
#                 close
# date
# 2009-05-18        NaN
# 2009-05-19        NaN
# 2009-05-20        NaN
# 2009-05-21        NaN
# 2009-05-22        NaN
# 2009-05-26        NaN
# 2009-05-27        NaN
# 2009-05-28        NaN
# 2009-05-29        NaN
# 2009-06-01        NaN
# 2009-06-02        NaN
# 2009-06-03        NaN
# 2009-06-04        NaN
# 2009-06-05        NaN
# 2009-06-08        NaN
# 2009-06-09        NaN
# 2009-06-10        NaN
# 2009-06-11        NaN
# 2009-06-12        NaN
# 2009-06-15        NaN
# 2009-06-16        NaN
# 2009-06-17        NaN
# 2009-06-18        NaN
# 2009-06-19        NaN
# 2009-06-22        NaN
# 2009-06-23        NaN
# 2009-06-24        NaN
# 2009-06-25        NaN
# 2009-06-26        NaN
# 2009-06-29        NaN
# ...               ...
# 2019-04-04  321.76835
# 2019-04-05  322.24405
# 2019-04-08  322.82345
# 2019-04-09  323.52985
# 2019-04-10  324.22505
# 2019-04-11  325.03425
# 2019-04-12  325.64505
# 2019-04-15  326.27165
# 2019-04-16  327.16025
# 2019-04-17  328.03785
# 2019-04-18  329.02005
# 2019-04-22  330.20525
# 2019-04-23  331.40985
# 2019-04-24  332.48585
# 2019-04-25  333.34265
# 2019-04-26  334.20365
# 2019-04-29  335.06065
# 2019-04-30  335.86305
# 2019-05-01  336.89785
# 2019-05-02  337.85965
# 2019-05-03  339.05855
# 2019-05-06  340.14825
# 2019-05-07  341.19965
# 2019-05-08  342.09455
# 2019-05-09  342.96185
# 2019-05-10  343.90385
# 2019-05-13  344.72845
# 2019-05-14  345.47515
# 2019-05-15  346.35735
# 2019-05-16  347.34465
#
# [2517 rows x 1 columns]

# %% [markdown]
# ### Overlay Daily Closing Prices of NFLX and SMAs

# %%
# Set figure of the daily closing prices of NFLX
ax = nflx_df.plot(figsize=(25,10))

# Overlay SMA20, SMA50, and SMA100 on the same figure
nflx_sma_20.plot(ax=ax)
nflx_sma_50.plot(ax=ax)
nflx_sma_100.plot(ax=ax)

# Set the legend of the figure
ax.legend(["Original", "SMA20", "SMA50", "SMA100"]);

# %% [markdown]
# ### Overlay Daily Closing Prices of NFLX and STDs

# %%
# Set figure of the daily closing prices of NFLX
ax = nflx_df.plot(figsize=(25,10))

# Overlay STD20, STD50, and STD100 on the same figure
nflx_df.rolling(window=20).std().plot(ax=ax)
nflx_df.rolling(window=50).std().plot(ax=ax)
nflx_df.rolling(window=100).std().plot(ax=ax)

# Set the legend of the figure
ax.legend(["Original", "STD20", "STD50", "STD100"]);

# %% [markdown]
# ### Should Harold's firm invest long term in NFLX?

# %% [markdown]
# Because Harold's company is looking to invest long term in NFLX, the `SMA100` and `STD100` should hold more emphasis. Based on the chart overlays, although there is a recent price uptrend in late 2018, long-term volatility has been high for the entirety of 2018 to 2019. Therefore, it may best to hold off on investing in NFLX long term for now.
